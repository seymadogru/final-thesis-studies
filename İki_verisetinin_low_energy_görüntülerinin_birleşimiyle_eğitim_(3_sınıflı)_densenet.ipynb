# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense
from keras.applications.vgg16 import VGG16
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob
import cv2

# %%
train_dir = "/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Train"
test_dir = "/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Test"

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Out:
# --2024-07-30 12:16:50--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2024-07-30 12:16:50 (127 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, walk_through_dir

# %%
import os

for dirpath, dirnames, filenames in os.walk("/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı'.
# There are 3 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Train'.
# There are 0 directories and 655 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Train/Normal'.
# There are 0 directories and 420 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Train/Malignant'.
# There are 0 directories and 325 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Train/Benign'.
# There are 3 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Test'.
# There are 0 directories and 72 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Test/Normal'.
# There are 0 directories and 50 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Test/Malignant'.
# There are 0 directories and 50 images in '/content/drive/MyDrive/Tez Dosyaları/low energy 3 classlı/Test/Benign'.

# %%
import tensorflow as tf
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
train_data= tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                          label_mode= "categorical",
                                                          batch_size=BATCH_SIZE,
                                                          image_size=IMG_SIZE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                          label_mode="categorical",
                                                          batch_size=BATCH_SIZE,
                                                          image_size=IMG_SIZE)
# Out:
# Found 1400 files belonging to 3 classes.
# Found 172 files belonging to 3 classes.

# %%
train_data.class_names
# Out:
# ['Benign', 'Malignant', 'Normal']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
import numpy as np
import random
import math
import csv
import cv2
import os

# %%
import tensorflow as tf

# 1. create base model with tf.keras.applications
base_model = tf.keras.applications.DenseNet121(include_top=False)

# 2. Freeze the base model
base_model.trainable = False

# 3. create inputs into our model
inputs = tf.keras.layers.Input(shape=(224, 224, 3), name="input_layer")

# 4. if using ResNet50V2 you will need to normalize inputs
# x = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)(inputs)

# 5. pass the inputs to the base_model
x = base_model(inputs)
print(f"Shape after passing inputs through base model: {x.shape}")

# 6. average pool the outputs of the base model (aggregate all the most important information, reduce number of computations)
x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)
print(f"Shape after GlobalAveragePooling2D: {x.shape}")

# 7. create the output activation layer for 3 classes
outputs = tf.keras.layers.Dense(3, activation="softmax", name="output_layer")(x)
model_0 = tf.keras.Model(inputs, outputs)

# 8. compile the model for 3 classes
model_0.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# Assuming you have already prepared your train_data and test_data
# Make sure that train_data and test_data are prepared with class_mode='categorical'

# 9. fit the model
history_0 = model_0.fit(train_data,
                        epochs=40,
                        steps_per_epoch=len(train_data),
                        validation_data=test_data,
                        validation_steps=int(len(test_data)),
                        callbacks=[create_tensorboard_callback(dir_name="transfer_learning",
                                                               experiment_name="3_class_feature_extraction")])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step
# Shape after passing inputs through base model: (None, 7, 7, 1024)
# Shape after GlobalAveragePooling2D: (None, 1024)
# Saving TensorBoard log files to: transfer_learning/3_class_feature_extraction/20240730-124038
# Epoch 1/40
# 44/44 [==============================] - 28s 386ms/step - loss: 1.2869 - accuracy: 0.4571 - val_loss: 1.3386 - val_accuracy: 0.4302
# Epoch 2/40
# 44/44 [==============================] - 10s 199ms/step - loss: 1.0851 - accuracy: 0.4950 - val_loss: 1.2874 - val_accuracy: 0.4477
# Epoch 3/40
# 44/44 [==============================] - 10s 193ms/step - loss: 1.0271 - accuracy: 0.5143 - val_loss: 1.3214 - val_accuracy: 0.4419
# Epoch 4/40
# 44/44 [==============================] - 10s 190ms/step - loss: 0.9780 - accuracy: 0.5350 - val_loss: 1.2262 - val_accuracy: 0.4651
# Epoch 5/40
# 44/44 [==============================] - 10s 197ms/step - loss: 0.9580 - accuracy: 0.5443 - val_loss: 1.1766 - val_accuracy: 0.4767
# Epoch 6/40
# 44/44 [==============================] - 10s 199ms/step - loss: 0.9226 - accuracy: 0.5886 - val_loss: 1.0685 - val_accuracy: 0.5174
# Epoch 7/40
# 44/44 [==============================] - 10s 200ms/step - loss: 0.9037 - accuracy: 0.5843 - val_loss: 1.0511 - val_accuracy: 0.5291
# Epoch 8/40
# 44/44 [==============================] - 10s 196ms/step - loss: 0.8897 - accuracy: 0.5850 - val_loss: 1.3629 - val_accuracy: 0.4826
# Epoch 9/40
# 44/44 [==============================] - 10s 196ms/step - loss: 0.9118 - accuracy: 0.5921 - val_loss: 1.1293 - val_accuracy: 0.4942
# Epoch 10/40
# 44/44 [==============================] - 10s 197ms/step - loss: 0.8573 - accuracy: 0.6264 - val_loss: 1.1314 - val_accuracy: 0.5058
# Epoch 11/40
# 44/44 [==============================] - 10s 200ms/step - loss: 0.8591 - accuracy: 0.6164 - val_loss: 1.0400 - val_accuracy: 0.5465
# Epoch 12/40
# 44/44 [==============================] - 10s 201ms/step - loss: 0.8764 - accuracy: 0.6014 - val_loss: 1.0141 - val_accuracy: 0.5523
# Epoch 13/40
# 44/44 [==============================] - 10s 195ms/step - loss: 0.8235 - accuracy: 0.6386 - val_loss: 1.1088 - val_accuracy: 0.5174
# Epoch 14/40
# 44/44 [==============================] - 10s 195ms/step - loss: 0.8073 - accuracy: 0.6371 - val_loss: 1.1490 - val_accuracy: 0.5291
# Epoch 15/40
# 44/44 [==============================] - 10s 194ms/step - loss: 0.8154 - accuracy: 0.6486 - val_loss: 1.0567 - val_accuracy: 0.5349
# Epoch 16/40
# 44/44 [==============================] - 10s 202ms/step - loss: 0.8094 - accuracy: 0.6471 - val_loss: 1.0138 - val_accuracy: 0.5465
# Epoch 17/40
# 44/44 [==============================] - 10s 198ms/step - loss: 0.7947 - accuracy: 0.6486 - val_loss: 1.1926 - val_accuracy: 0.5058
# Epoch 18/40
# 44/44 [==============================] - 10s 200ms/step - loss: 0.8077 - accuracy: 0.6343 - val_loss: 1.1305 - val_accuracy: 0.5233
# Epoch 19/40
# 44/44 [==============================] - 10s 196ms/step - loss: 0.7708 - accuracy: 0.6500 - val_loss: 1.0280 - val_accuracy: 0.5407
# Epoch 20/40
# 44/44 [==============================] - 10s 198ms/step - loss: 0.7747 - accuracy: 0.6371 - val_loss: 1.1260 - val_accuracy: 0.5349
# Epoch 21/40
# 44/44 [==============================] - 10s 200ms/step - loss: 0.7749 - accuracy: 0.6650 - val_loss: 1.0746 - val_accuracy: 0.5000
# Epoch 22/40
# 44/44 [==============================] - 10s 199ms/step - loss: 0.8059 - accuracy: 0.6357 - val_loss: 1.0582 - val_accuracy: 0.5116
# Epoch 23/40
# 44/44 [==============================] - 10s 198ms/step - loss: 0.7552 - accuracy: 0.6743 - val_loss: 1.0960 - val_accuracy: 0.5581
# Epoch 24/40
# 44/44 [==============================] - 10s 195ms/step - loss: 0.7443 - accuracy: 0.6686 - val_loss: 1.1883 - val_accuracy: 0.5349
# Epoch 25/40
# 44/44 [==============================] - 10s 199ms/step - loss: 0.7400 - accuracy: 0.6721 - val_loss: 1.2241 - val_accuracy: 0.5407
# Epoch 26/40
# 44/44 [==============================] - 10s 199ms/step - loss: 0.7616 - accuracy: 0.6550 - val_loss: 1.1953 - val_accuracy: 0.5581
# Epoch 27/40
# 44/44 [==============================] - 10s 200ms/step - loss: 0.7375 - accuracy: 0.6643 - val_loss: 1.1692 - val_accuracy: 0.5465
# Epoch 28/40
# 44/44 [==============================] - 10s 196ms/step - loss: 0.7286 - accuracy: 0.6871 - val_loss: 1.5183 - val_accuracy: 0.4767
# Epoch 29/40
# 44/44 [==============================] - 10s 191ms/step - loss: 0.7703 - accuracy: 0.6643 - val_loss: 1.4462 - val_accuracy: 0.4942
# Epoch 30/40
# 44/44 [==============================] - 10s 200ms/step - loss: 0.7311 - accuracy: 0.6664 - val_loss: 1.0623 - val_accuracy: 0.5291
# Epoch 31/40
# 44/44 [==============================] - 10s 199ms/step - loss: 0.7160 - accuracy: 0.6871 - val_loss: 1.1725 - val_accuracy: 0.5581
# Epoch 32/40
# 44/44 [==============================] - 10s 196ms/step - loss: 0.6962 - accuracy: 0.7014 - val_loss: 1.1914 - val_accuracy: 0.5640
# Epoch 33/40
# 44/44 [==============================] - 10s 201ms/step - loss: 0.7062 - accuracy: 0.6943 - val_loss: 1.1764 - val_accuracy: 0.5465
# Epoch 34/40
# 44/44 [==============================] - 10s 196ms/step - loss: 0.6947 - accuracy: 0.6971 - val_loss: 1.1785 - val_accuracy: 0.5640
# Epoch 35/40
# 44/44 [==============================] - 10s 200ms/step - loss: 0.6843 - accuracy: 0.7093 - val_loss: 1.1680 - val_accuracy: 0.5233
# Epoch 36/40
# 44/44 [==============================] - 10s 202ms/step - loss: 0.7001 - accuracy: 0.6943 - val_loss: 1.2277 - val_accuracy: 0.5465
# Epoch 37/40
# 44/44 [==============================] - 10s 198ms/step - loss: 0.6965 - accuracy: 0.6814 - val_loss: 1.1849 - val_accuracy: 0.5465
# Epoch 38/40
# 44/44 [==============================] - 10s 194ms/step - loss: 0.6849 - accuracy: 0.7014 - val_loss: 1.2252 - val_accuracy: 0.5698
# Epoch 39/40
# 44/44 [==============================] - 10s 195ms/step - loss: 0.6831 - accuracy: 0.7121 - val_loss: 1.0827 - val_accuracy: 0.5174
# Epoch 40/40
# 44/44 [==============================] - 10s 202ms/step - loss: 0.6688 - accuracy: 0.7157 - val_loss: 1.1095 - val_accuracy: 0.5407

# %%
plot_loss_curves(history_0)

# %%
from sklearn.metrics import classification_report

# Assuming you have true labels for your test data stored in y_true
# and predictions from your model stored in y_pred

# Convert categorical predictions to class labels
y_pred_labels = np.argmax(model_0.predict(test_data), axis=1)

# Get true labels from the test dataset
y_true_labels = np.concatenate([y for x, y in test_data], axis=0)
y_true_labels = np.argmax(y_true_labels, axis=1)

# Generate classification report
report = classification_report(y_true_labels, y_pred_labels)

print(report)
# Out:
# 6/6 [==============================] - 3s 97ms/step
#               precision    recall  f1-score   support
#
#            0       0.30      0.14      0.19        50
#            1       0.31      0.30      0.30        50
#            2       0.43      0.60      0.50        72
#
#     accuracy                           0.38       172
#    macro avg       0.35      0.35      0.33       172
# weighted avg       0.36      0.38      0.35       172

# %%
# Eğitim doğruluğunu geçmiş verilerinden al
train_accuracy = history_0.history['accuracy']

# Son epoch'un eğitim doğruluğunu yazdır
print("Eğitim doğruluğu:", train_accuracy[-1])
# Out:
# Eğitim doğruluğu: 0.7157142758369446

# %%
# test verisinin doğruluğunu hesapla
test_loss, test_accuracy = model_0.evaluate(test_data)
print("Test doğruluğu:", test_accuracy)
# Out:
# 6/6 [==============================] - 2s 84ms/step - loss: 1.1095 - accuracy: 0.5407
# Test doğruluğu: 0.5406976938247681
