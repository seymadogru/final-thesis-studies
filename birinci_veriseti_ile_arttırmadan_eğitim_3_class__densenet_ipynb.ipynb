# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense
from keras.applications.vgg16 import VGG16
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob
import cv2

# %%
train_dir = "/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Train"
test_dir = "/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Test"

# %%
numberOfClass = len(glob(train_dir + "/*"))

# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Out:
# --2024-07-23 12:58:16--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2024-07-23 12:58:16 (101 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, walk_through_dir

# %%
import os

for dirpath, dirnames, filenames in os.walk("/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı'.
# There are 3 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Train'.
# There are 0 directories and 680 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Train/Normal'.
# There are 0 directories and 596 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Train/Malignant'.
# There are 0 directories and 527 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Train/Benign'.
# There are 3 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Test'.
# There are 0 directories and 60 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Test/Benign'.
# There are 0 directories and 66 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Test/Malignant'.
# There are 0 directories and 77 images in '/content/drive/MyDrive/Tez Dosyaları/birinci veriseti 3 classlı/Test/Normal'.

# %%
import tensorflow as tf
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
train_data= tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                          label_mode= "categorical",
                                                          batch_size=BATCH_SIZE,
                                                          image_size=IMG_SIZE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                          label_mode="categorical",
                                                          batch_size=BATCH_SIZE,
                                                          image_size=IMG_SIZE)
# Out:
# Found 1803 files belonging to 3 classes.
# Found 203 files belonging to 3 classes.

# %%
train_data.class_names
# Out:
# ['Benign', 'Malignant', 'Normal']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
import numpy as np
import random
import math
import csv
import cv2
import os

# %%
# 1. create base model with tf.keras.applications
base_model = tf.keras.applications.DenseNet121(include_top=False)

# 2. Freeze the base model
base_model.trainable = False

# 3. create inputs into our model
inputs = tf.keras.layers.Input(shape=(224, 224, 3), name="input_layer")

# 4. if using ResNet50V2 you will need to normalize inputs
# x = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)(inputs)

# 5. pass the inputs to the base_model
x = base_model(inputs)
print(f"Shape after passing inputs through base model: {x.shape}")

# 6. average pool the outputs of the base model (aggregate all the most important information, reduce number of computations)
x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)
print(f"Shape after GlobalAveragePooling2D: {x.shape}")

# 7. create the output activation layer for 3 classes
outputs = tf.keras.layers.Dense(3, activation="softmax", name="output_layer")(x)
model_0 = tf.keras.Model(inputs, outputs)

# 8. compile the model for 3 classes
model_0.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# Assuming you have already prepared your train_data and test_data
# Make sure that train_data and test_data are prepared with class_mode='categorical'

# 9. fit the model
history_0 = model_0.fit(train_data,
                        epochs=40,
                        steps_per_epoch=len(train_data),
                        validation_data=test_data,
                        validation_steps=int(len(test_data)),
                        callbacks=[create_tensorboard_callback(dir_name="transfer_learning",
                                                               experiment_name="3_class_feature_extraction")])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step
# Shape after passing inputs through base model: (None, 7, 7, 1024)
# Shape after GlobalAveragePooling2D: (None, 1024)
# Saving TensorBoard log files to: transfer_learning/3_class_feature_extraction/20240723-125941
# Epoch 1/40
# 57/57 [==============================] - 239s 3s/step - loss: 1.3695 - accuracy: 0.3821 - val_loss: 1.2890 - val_accuracy: 0.4089
# Epoch 2/40
# 57/57 [==============================] - 11s 177ms/step - loss: 1.1558 - accuracy: 0.4293 - val_loss: 1.2612 - val_accuracy: 0.3990
# Epoch 3/40
# 57/57 [==============================] - 11s 177ms/step - loss: 1.1096 - accuracy: 0.4382 - val_loss: 1.1960 - val_accuracy: 0.4138
# Epoch 4/40
# 57/57 [==============================] - 11s 177ms/step - loss: 1.0569 - accuracy: 0.4698 - val_loss: 1.1606 - val_accuracy: 0.4532
# Epoch 5/40
# 57/57 [==============================] - 11s 174ms/step - loss: 1.0109 - accuracy: 0.5031 - val_loss: 1.1533 - val_accuracy: 0.4483
# Epoch 6/40
# 57/57 [==============================] - 11s 174ms/step - loss: 1.0216 - accuracy: 0.4958 - val_loss: 1.1066 - val_accuracy: 0.4631
# Epoch 7/40
# 57/57 [==============================] - 11s 174ms/step - loss: 0.9619 - accuracy: 0.5397 - val_loss: 1.1382 - val_accuracy: 0.4680
# Epoch 8/40
# 57/57 [==============================] - 11s 177ms/step - loss: 0.9790 - accuracy: 0.5169 - val_loss: 1.2568 - val_accuracy: 0.4335
# Epoch 9/40
# 57/57 [==============================] - 11s 176ms/step - loss: 0.9511 - accuracy: 0.5374 - val_loss: 1.0737 - val_accuracy: 0.4926
# Epoch 10/40
# 57/57 [==============================] - 11s 177ms/step - loss: 0.9375 - accuracy: 0.5458 - val_loss: 1.1212 - val_accuracy: 0.4384
# Epoch 11/40
# 57/57 [==============================] - 11s 172ms/step - loss: 0.9447 - accuracy: 0.5446 - val_loss: 1.0822 - val_accuracy: 0.4877
# Epoch 12/40
# 57/57 [==============================] - 11s 179ms/step - loss: 0.8819 - accuracy: 0.5890 - val_loss: 1.0590 - val_accuracy: 0.4926
# Epoch 13/40
# 57/57 [==============================] - 11s 170ms/step - loss: 0.9064 - accuracy: 0.5707 - val_loss: 1.0996 - val_accuracy: 0.4581
# Epoch 14/40
# 57/57 [==============================] - 11s 171ms/step - loss: 0.8765 - accuracy: 0.5862 - val_loss: 1.1516 - val_accuracy: 0.4778
# Epoch 15/40
# 57/57 [==============================] - 11s 174ms/step - loss: 0.8709 - accuracy: 0.5907 - val_loss: 1.0657 - val_accuracy: 0.4975
# Epoch 16/40
# 57/57 [==============================] - 11s 177ms/step - loss: 0.8511 - accuracy: 0.6212 - val_loss: 1.1205 - val_accuracy: 0.4778
# Epoch 17/40
# 57/57 [==============================] - 11s 178ms/step - loss: 0.8494 - accuracy: 0.6123 - val_loss: 1.0688 - val_accuracy: 0.4975
# Epoch 18/40
# 57/57 [==============================] - 11s 174ms/step - loss: 0.8392 - accuracy: 0.6312 - val_loss: 1.0543 - val_accuracy: 0.5025
# Epoch 19/40
# 57/57 [==============================] - 11s 173ms/step - loss: 0.8523 - accuracy: 0.5979 - val_loss: 1.1698 - val_accuracy: 0.4384
# Epoch 20/40
# 57/57 [==============================] - 11s 171ms/step - loss: 0.8462 - accuracy: 0.6118 - val_loss: 1.0812 - val_accuracy: 0.4532
# Epoch 21/40
# 57/57 [==============================] - 11s 172ms/step - loss: 0.8318 - accuracy: 0.6173 - val_loss: 1.1224 - val_accuracy: 0.4384
# Epoch 22/40
# 57/57 [==============================] - 11s 171ms/step - loss: 0.8490 - accuracy: 0.6023 - val_loss: 1.0771 - val_accuracy: 0.4926
# Epoch 23/40
# 57/57 [==============================] - 11s 175ms/step - loss: 0.8335 - accuracy: 0.6267 - val_loss: 1.1454 - val_accuracy: 0.5123
# Epoch 24/40
# 57/57 [==============================] - 12s 179ms/step - loss: 0.8176 - accuracy: 0.6378 - val_loss: 1.1397 - val_accuracy: 0.4335
# Epoch 25/40
# 57/57 [==============================] - 11s 177ms/step - loss: 0.8192 - accuracy: 0.6351 - val_loss: 1.1119 - val_accuracy: 0.4631
# Epoch 26/40
# 57/57 [==============================] - 11s 178ms/step - loss: 0.8002 - accuracy: 0.6412 - val_loss: 1.0892 - val_accuracy: 0.4975
# Epoch 27/40
# 57/57 [==============================] - 11s 174ms/step - loss: 0.8121 - accuracy: 0.6417 - val_loss: 1.0725 - val_accuracy: 0.5025
# Epoch 28/40
# 57/57 [==============================] - 11s 176ms/step - loss: 0.8022 - accuracy: 0.6323 - val_loss: 1.0950 - val_accuracy: 0.4680
# Epoch 29/40
# 57/57 [==============================] - 11s 172ms/step - loss: 0.7822 - accuracy: 0.6539 - val_loss: 1.0926 - val_accuracy: 0.4828
# Epoch 30/40
# 57/57 [==============================] - 11s 175ms/step - loss: 0.7923 - accuracy: 0.6539 - val_loss: 1.1438 - val_accuracy: 0.5172
# Epoch 31/40
# 57/57 [==============================] - 11s 176ms/step - loss: 0.7929 - accuracy: 0.6500 - val_loss: 1.1411 - val_accuracy: 0.4335
# Epoch 32/40
# 57/57 [==============================] - 12s 183ms/step - loss: 0.8044 - accuracy: 0.6334 - val_loss: 1.0857 - val_accuracy: 0.4778
# Epoch 33/40
# 57/57 [==============================] - 11s 179ms/step - loss: 0.7879 - accuracy: 0.6450 - val_loss: 1.1453 - val_accuracy: 0.4433
# Epoch 34/40
# 57/57 [==============================] - 11s 176ms/step - loss: 0.7940 - accuracy: 0.6456 - val_loss: 1.0959 - val_accuracy: 0.4631
# Epoch 35/40
# 57/57 [==============================] - 11s 174ms/step - loss: 0.7704 - accuracy: 0.6661 - val_loss: 1.0957 - val_accuracy: 0.4680
# Epoch 36/40
# 57/57 [==============================] - 11s 173ms/step - loss: 0.7790 - accuracy: 0.6611 - val_loss: 1.1095 - val_accuracy: 0.5074
# Epoch 37/40
# 57/57 [==============================] - 11s 174ms/step - loss: 0.7585 - accuracy: 0.6733 - val_loss: 1.1151 - val_accuracy: 0.4483
# Epoch 38/40
# 57/57 [==============================] - 11s 171ms/step - loss: 0.8151 - accuracy: 0.6400 - val_loss: 1.0805 - val_accuracy: 0.4877
# Epoch 39/40
# 57/57 [==============================] - 11s 172ms/step - loss: 0.7594 - accuracy: 0.6761 - val_loss: 1.1205 - val_accuracy: 0.4631
# Epoch 40/40
# 57/57 [==============================] - 11s 177ms/step - loss: 0.7655 - accuracy: 0.6484 - val_loss: 1.0837 - val_accuracy: 0.4729

# %%
# Evaluate the model on the test data
results_feature_extraction = model_0.evaluate(test_data)
results_feature_extraction
# Out:
# 7/7 [==============================] - 2s 82ms/step - loss: 1.0837 - accuracy: 0.4729
# [1.0836983919143677, 0.4729064106941223]

# %%
plot_loss_curves(history_0)

# %%
from sklearn.metrics import classification_report

# Assuming you have true labels for your test data stored in y_true
# and predictions from your model stored in y_pred

# Convert categorical predictions to class labels
y_pred_labels = np.argmax(model_0.predict(test_data), axis=1)

# Get true labels from the test dataset
y_true_labels = np.concatenate([y for x, y in test_data], axis=0)
y_true_labels = np.argmax(y_true_labels, axis=1)

# Generate classification report
report = classification_report(y_true_labels, y_pred_labels)

print(report)
# Out:
# 7/7 [==============================] - 3s 99ms/step
#               precision    recall  f1-score   support
#
#            0       0.33      0.22      0.26        60
#            1       0.32      0.39      0.35        66
#            2       0.38      0.40      0.39        77
#
#     accuracy                           0.34       203
#    macro avg       0.34      0.34      0.33       203
# weighted avg       0.34      0.34      0.34       203
