# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Out:
# --2024-07-25 19:11:18--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2024-07-25 19:11:19 (126 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, walk_through_dir

# %%
import os

for dirpath, dirnames, filenames in os.walk("/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli"):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 2 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli'.
# There are 2 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Train'.
# There are 0 directories and 840 images in '/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Train/Malignant'.
# There are 0 directories and 575 images in '/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Train/Benign'.
# There are 2 directories and 0 images in '/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Test'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Test/Benign'.
# There are 0 directories and 100 images in '/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Test/Malignant'.

# %%
train_dir = "/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Train"
test_dir = "/content/drive/MyDrive/Tez Dosyaları/birlesik veriseti 2 classli/Test"

# %%
import tensorflow as tf
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
train_data= tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                          label_mode="binary",
                                                          batch_size=BATCH_SIZE,
                                                          image_size=IMG_SIZE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                          label_mode="binary",
                                                          batch_size=BATCH_SIZE,
                                                          image_size=IMG_SIZE)
# Out:
# Found 1415 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %%
train_data.class_names
# Out:
# ['Benign', 'Malignant']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
import numpy as np
import random
import math
import csv
import cv2
import os

# %%
# 1.  create base model with tf.keras.applications
base_model = tf.keras.applications.ResNet50(include_top=False)

# 2. Freeze the base model
base_model.trainable = False

# 3. create inputs into our model
inputs = tf.keras.layers.Input(shape=(224, 224, 3), name="input_layer")

# 4. if using ResNet50V2 you will need to normalize inputs
# x = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)(inputs)

# 5. pass the inputs to the base_model
x = base_model(inputs)
print(f"Shape after passing inputs through base model: {x.shape}")

# 6. average pool the outputs of the base model (aggregate all the most important information, reduce number of computations)
x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)
print(f"Shape after GlobalAveragePooling2D: {x.shape}")

# 7. create the output activation layer
outputs = tf.keras.layers.Dense(1, activation="sigmoid", name="output_layer")(x)
model_0 = tf.keras.Model(inputs, outputs)

# 8. compile the model
model_0.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"])

# 9. fit the model
history_0 = model_0.fit(train_data,
                        epochs=40,
                        steps_per_epoch=len(train_data),
                        validation_data=test_data,
                        validation_steps=int(len(test_data)),
                        callbacks=[create_tensorboard_callback(dir_name="transfer_learning",
                                                              experiment_name="10_percent_feature_extraction")])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Shape after passing inputs through base model: (None, 7, 7, 2048)
# Shape after GlobalAveragePooling2D: (None, 2048)
# Saving TensorBoard log files to: transfer_learning/10_percent_feature_extraction/20240725-192816
# Epoch 1/40
# 45/45 [==============================] - 18s 253ms/step - loss: 0.6877 - accuracy: 0.5894 - val_loss: 0.7377 - val_accuracy: 0.5250
# Epoch 2/40
# 45/45 [==============================] - 10s 193ms/step - loss: 0.6124 - accuracy: 0.6622 - val_loss: 0.6785 - val_accuracy: 0.5750
# Epoch 3/40
# 45/45 [==============================] - 10s 189ms/step - loss: 0.5910 - accuracy: 0.6792 - val_loss: 0.6145 - val_accuracy: 0.6850
# Epoch 4/40
# 45/45 [==============================] - 10s 186ms/step - loss: 0.5655 - accuracy: 0.6968 - val_loss: 0.6269 - val_accuracy: 0.6800
# Epoch 5/40
# 45/45 [==============================] - 10s 193ms/step - loss: 0.5480 - accuracy: 0.7053 - val_loss: 0.6117 - val_accuracy: 0.6750
# Epoch 6/40
# 45/45 [==============================] - 10s 195ms/step - loss: 0.5435 - accuracy: 0.7124 - val_loss: 0.6206 - val_accuracy: 0.6800
# Epoch 7/40
# 45/45 [==============================] - 10s 191ms/step - loss: 0.5160 - accuracy: 0.7350 - val_loss: 0.6214 - val_accuracy: 0.6750
# Epoch 8/40
# 45/45 [==============================] - 10s 190ms/step - loss: 0.5053 - accuracy: 0.7505 - val_loss: 0.6150 - val_accuracy: 0.6950
# Epoch 9/40
# 45/45 [==============================] - 10s 190ms/step - loss: 0.5028 - accuracy: 0.7498 - val_loss: 0.6594 - val_accuracy: 0.6550
# Epoch 10/40
# 45/45 [==============================] - 10s 197ms/step - loss: 0.5084 - accuracy: 0.7491 - val_loss: 0.6212 - val_accuracy: 0.7100
# Epoch 11/40
# 45/45 [==============================] - 10s 192ms/step - loss: 0.4881 - accuracy: 0.7562 - val_loss: 0.6326 - val_accuracy: 0.6900
# Epoch 12/40
# 45/45 [==============================] - 10s 190ms/step - loss: 0.4722 - accuracy: 0.7767 - val_loss: 0.6349 - val_accuracy: 0.6950
# Epoch 13/40
# 45/45 [==============================] - 10s 188ms/step - loss: 0.4698 - accuracy: 0.7809 - val_loss: 0.6913 - val_accuracy: 0.6100
# Epoch 14/40
# 45/45 [==============================] - 10s 191ms/step - loss: 0.4727 - accuracy: 0.7689 - val_loss: 0.6412 - val_accuracy: 0.6750
# Epoch 15/40
# 45/45 [==============================] - 10s 191ms/step - loss: 0.4594 - accuracy: 0.7830 - val_loss: 0.6215 - val_accuracy: 0.7000
# Epoch 16/40
# 45/45 [==============================] - 10s 189ms/step - loss: 0.4462 - accuracy: 0.8035 - val_loss: 0.6430 - val_accuracy: 0.6750
# Epoch 17/40
# 45/45 [==============================] - 10s 189ms/step - loss: 0.4411 - accuracy: 0.7943 - val_loss: 0.6183 - val_accuracy: 0.7150
# Epoch 18/40
# 45/45 [==============================] - 10s 187ms/step - loss: 0.4380 - accuracy: 0.7986 - val_loss: 0.6602 - val_accuracy: 0.6500
# Epoch 19/40
# 45/45 [==============================] - 10s 195ms/step - loss: 0.4301 - accuracy: 0.8120 - val_loss: 0.6118 - val_accuracy: 0.7100
# Epoch 20/40
# 45/45 [==============================] - 10s 193ms/step - loss: 0.4227 - accuracy: 0.8170 - val_loss: 0.6399 - val_accuracy: 0.6850
# Epoch 21/40
# 45/45 [==============================] - 10s 189ms/step - loss: 0.4234 - accuracy: 0.8113 - val_loss: 0.6637 - val_accuracy: 0.6700
# Epoch 22/40
# 45/45 [==============================] - 10s 186ms/step - loss: 0.4228 - accuracy: 0.8120 - val_loss: 0.6263 - val_accuracy: 0.6800
# Epoch 23/40
# 45/45 [==============================] - 10s 194ms/step - loss: 0.4271 - accuracy: 0.8071 - val_loss: 0.6190 - val_accuracy: 0.7250
# Epoch 24/40
# 45/45 [==============================] - 10s 194ms/step - loss: 0.4018 - accuracy: 0.8254 - val_loss: 0.6473 - val_accuracy: 0.6700
# Epoch 25/40
# 45/45 [==============================] - 10s 190ms/step - loss: 0.3990 - accuracy: 0.8276 - val_loss: 0.6444 - val_accuracy: 0.6800
# Epoch 26/40
# 45/45 [==============================] - 10s 187ms/step - loss: 0.4012 - accuracy: 0.8205 - val_loss: 0.6320 - val_accuracy: 0.6800
# Epoch 27/40
# 45/45 [==============================] - 10s 192ms/step - loss: 0.3887 - accuracy: 0.8417 - val_loss: 0.6286 - val_accuracy: 0.6800
# Epoch 28/40
# 45/45 [==============================] - 10s 195ms/step - loss: 0.3831 - accuracy: 0.8438 - val_loss: 0.6334 - val_accuracy: 0.6950
# Epoch 29/40
# 45/45 [==============================] - 10s 197ms/step - loss: 0.3874 - accuracy: 0.8367 - val_loss: 0.6386 - val_accuracy: 0.7000
# Epoch 30/40
# 45/45 [==============================] - 10s 190ms/step - loss: 0.3758 - accuracy: 0.8650 - val_loss: 0.6585 - val_accuracy: 0.6850
# Epoch 31/40
# 45/45 [==============================] - 10s 186ms/step - loss: 0.3693 - accuracy: 0.8523 - val_loss: 0.6320 - val_accuracy: 0.6850
# Epoch 32/40
# 45/45 [==============================] - 10s 190ms/step - loss: 0.3699 - accuracy: 0.8530 - val_loss: 0.6376 - val_accuracy: 0.6850
# Epoch 33/40
# 45/45 [==============================] - 10s 193ms/step - loss: 0.3754 - accuracy: 0.8424 - val_loss: 0.6307 - val_accuracy: 0.6750
# Epoch 34/40
# 45/45 [==============================] - 10s 192ms/step - loss: 0.3668 - accuracy: 0.8537 - val_loss: 0.6334 - val_accuracy: 0.6900
# Epoch 35/40
# 45/45 [==============================] - 10s 187ms/step - loss: 0.3540 - accuracy: 0.8657 - val_loss: 0.6364 - val_accuracy: 0.6800
# Epoch 36/40
# 45/45 [==============================] - 10s 187ms/step - loss: 0.3643 - accuracy: 0.8410 - val_loss: 0.6437 - val_accuracy: 0.6850
# Epoch 37/40
# 45/45 [==============================] - 10s 195ms/step - loss: 0.3517 - accuracy: 0.8650 - val_loss: 0.6379 - val_accuracy: 0.7050
# Epoch 38/40
# 45/45 [==============================] - 10s 194ms/step - loss: 0.3459 - accuracy: 0.8735 - val_loss: 0.6586 - val_accuracy: 0.6650
# Epoch 39/40
# 45/45 [==============================] - 10s 192ms/step - loss: 0.3546 - accuracy: 0.8565 - val_loss: 0.6445 - val_accuracy: 0.6850
# Epoch 40/40
# 45/45 [==============================] - 10s 191ms/step - loss: 0.3389 - accuracy: 0.8770 - val_loss: 0.6723 - val_accuracy: 0.6500

# %%
import matplotlib.pyplot as plt

def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  Args:
    history: TensorFlow History object.

    Returns:
    Plots of training/validation loss and accuracy metrics.
  """
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  #Plot loss

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  #Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

plot_loss_curves(history_0)

# %%
results_feature_extraction = model_0.evaluate(test_data)
results_feature_extraction
# Out:
# 7/7 [==============================] - 2s 87ms/step - loss: 0.6723 - accuracy: 0.6500
# [0.6723020672798157, 0.6499999761581421]

# %%
# Get the predicted probabilities for the test set
y_pred_probs = model_0.predict(test_data)

# Convert probabilities to binary predictions (0 or 1)
y_pred = (y_pred_probs > 0.5).astype(int)

# Get the true labels for the test set
y_true = np.concatenate([y for x, y in test_data], axis=0)

# Calculate precision
from sklearn.metrics import precision_score
precision = precision_score(y_true, y_pred)
print("Precision:", precision)
# Out:
# 7/7 [==============================] - 3s 102ms/step
# Precision: 0.525

# %%
from sklearn.metrics import recall_score

# Calculate recall
recall = recall_score(y_true, y_pred)
print("Recall:", recall)
# Out:
# Recall: 0.63

# %%
from sklearn.metrics import f1_score
# Calculate F1-score
f1 = f1_score(y_true, y_pred)
print("F1-score:", f1)
# Out:
# F1-score: 0.5727272727272728

# %%
# Eğitim doğruluğunu elde etmek için history_0 nesnesini kullanın
train_accuracy = history_0.history['accuracy']

# Son epoch'un eğitim doğruluğunu yazdırın
print("Eğitim doğruluğu:", train_accuracy[-1])
# Out:
# Eğitim doğruluğu: 0.8770318031311035
